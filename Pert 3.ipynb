# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/LENOVO/OneDrive/Diva Alvania/Semester 6/Pembelajaran Mesin/test.csv')
df1
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
df2 = df1.dropna()
df2
# Out:
#       x          y
# 0    77  79.775152
# 1    21  23.177279
# 2    22  25.609262
# 3    20  17.857388
# 4    36  41.849864
# ..   ..        ...
# 295  71  68.545888
# 296  46  47.334876
# 297  55  54.090637
# 298  62  63.297171
# 299  47  52.459467
#
# [300 rows x 2 columns]

# %%
df2.describe()
# Out:
#                 x           y
# count  300.000000  300.000000
# mean    50.936667   51.205051
# std     28.504286   29.071481
# min      0.000000   -3.467884
# 25%     27.000000   25.676502
# 50%     53.000000   52.170557
# 75%     73.000000   74.303007
# max    100.000000  105.591837

# %%
#bagi data menjadi test dan train
import sklearn.model_selection as ms
x=df2[['x']]
y=df2[['y']]
X_train, X_test, y_train, y_test = ms.train_test_split(x,y,test_size=0.2, random_state=0)
print(X_train.size, X_test.size)
#membagi test 20% dan train 80%
# Out:
# 240 60

# %% [markdown]
# Visualisasi

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.scatter(X_train,y_train, edgecolors='y')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot antara x dan y')
x1 = np.linspace(0,106)
y1 = -0.53332421 + 1.0144497*x1
plt.plot(x1,y1)
plt.show()

# %%
import sklearn.linear_model as lm
model1 = lm.LinearRegression()
model1.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model1.coef_
# Out:
# array([[1.0144497]])

# %%
model1.intercept_
# Out:
# array([-0.53332421])

# %%
r2 = model1.predict([[50]])
print(r2)
# Out:
# [[50.18916058]]
# c:\anaconda\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
jarak = model1.predict([[50]])
print(jarak)
# Out:
# [[50.18916058]]
# c:\anaconda\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
X_test
# Out:
#        x
# 208   67
# 188   27
# 12    96
# 221  100
# 239   28
# 136   65
# 230   37
# 206   40
# 52    52
# 108   89
# 290   92
# 15    15
# 184   37
# 248   90
# 22    89
# 74    15
# 270   55
# 90    67
# 229   14
# 164   49
# 190   92
# 103   74
# 124   41
# 129   29
# 222   48
# 116   17
# 194   61
# 286   16
# 234   65
# 295   71
# 92    63
# 66    41
# 8     20
# 122   98
# 219    4
# 150   60
# 176   58
# 182   93
# 299   47
# 5     15
# 223   42
# 89    43
# 81    27
# 34    28
# 55     0
# 139   53
# 236   56
# 64    82
# 7     95
# 45    37
# 73    53
# 213   44
# 173   56
# 106    1
# 59    57
# 253   60
# 168   21
# 26    79
# 284   59
# 153   84

# %%
y_test
# Out:
#               y
# 208   68.488207
# 188   30.494129
# 12    95.149072
# 221  103.526616
# 239   28.156685
# 136   68.946998
# 230   40.007096
# 206   48.098431
# 52    54.081706
# 108   87.457216
# 290   91.308637
# 15    14.822486
# 184   34.124732
# 248   89.899991
# 22    89.826344
# 74    13.256906
# 270   55.816285
# 90    67.021506
# 229   12.426246
# 164   52.286206
# 190   89.731536
# 103   75.692986
# 124   45.445996
# 129   26.494880
# 222   47.410067
# 116   13.413108
# 194   60.071375
# 286   16.749239
# 234   66.614996
# 295   68.545888
# 92    58.614669
# 66    38.688887
# 8     18.395127
# 122   95.580172
# 219    7.646530
# 150   59.831397
# 176   57.487414
# 182   99.435779
# 299   52.459467
# 5      9.805235
# 223   42.038358
# 89    48.672526
# 81    23.444792
# 34    33.071128
# 55    -1.040114
# 139   60.207583
# 236   57.191035
# 64    85.455042
# 7     97.617937
# 45    36.113348
# 73    50.170086
# 213   45.963969
# 173   54.554470
# 106    0.275307
# ...

# %%
predict = model1.predict([[67]])
predict
# Out:
# c:\anaconda\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[67.43480541]])

# %% [markdown]
# Multiple Linear Regression

# %%
df = pd.read_csv('C:/Users/LENOVO/OneDrive/Diva Alvania/Semester 6/Pembelajaran Mesin/kc_house_data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
#agar pembuatan model tidak sia-sia, maka asumsinya dibenarkan. jika terdapat variabel yang tidak berpengaruh, maka lebih baik dibuang

# %%
df.corr(method='pearson')
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
import sklearn.model_selection as ms

# %%
import sklearn.model_selection as ms
x1=df[['bathrooms','sqft_living']]
y1=df[['price']]
X1_train, X1_test, y1_train, y1_test = ms.train_test_split(x1,y1,test_size=0.2, random_state=0)
print(X1_train.size, X1_test.size)
# Out:
# 34580 8646

# %%
model = lm.LinearRegression()
model.fit(X1_train,y1_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([[-6095.34958438,   287.8115883 ]])

# %%
model.intercept_
# Out:
# array([-43344.28918513])

# %%
data1 = np.array([[3,2000]])
harga = model.predict(data1)
print(harga)
# Out:
# [[513992.8386712]]
# c:\anaconda\lib\site-packages\sklearn\base.py:409: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
r2 = model.score(X1_test, y1_test)
print (r2)
# Out:
# 0.4791133140827757
